# %%
import sys
sys.path.append("../")

# %%
from helpers.pubmed import PubmedAPI
pubmed = PubmedAPI("asamatt@umich.edu", True)

# %%
pubmed.search("Can you give me a brief summary on latest brucella research?", 15, "abstract")
# Out:
# ...
# in _rephrase_user_query, user query: Can you give me a brief summary on latest brucella research? rephrased as: brucella research latest
# ...
# brucella research latest
# ...
